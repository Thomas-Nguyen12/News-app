# %% [markdown]
# # Project Description
#
# This project will use Natural language processing (NLP) techniques to collect news reports and analyse them,
# fulfilling the following <b>aims</b>:
#
#
# 1. Sentiment Analysis (classify the news report into positive, negative, or neutral)
# 2. Chatbot that can summarise the news reports
# 3.  ***aspirational***: Generative AI to predict news reports

# %%
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats 
import numpy as np 
import requests 
import json

# %% [markdown]
# # Data Collection

# %%
# Current top headlines
url = "https://api.thenewsapi.com/v1/news/all?api_token=FwP6OI9ed4hixbo6HNr3vhKPxKS3iqRjkqwHGJx3&language=en&limit=3"
url = "https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=762f924e2bd9490382a4b4176ad8dec2"

response = requests.get(url)
print (response.status_code)
# Out:
# 200

# %%
response.text
# Out:
# '{"status":"ok","totalResults":10,"articles":[{"source":{"id":"bbc-news","name":"BBC News"},"author":"BBC News","title":"Beef drives food inflation to highest in a year","description":"The British Retail Consortium says the annual rate of food price rises hit 2.8% in May.","url":"https://www.bbc.co.uk/news/articles/ckg41n37990o","urlToImage":"https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/2274/live/40dc7be0-3ad2-11f0-bb33-cb43edff610f.jpg","publishedAt":"2025-05-27T10:37:23.9259172Z","content":"Jilly Greed, a fourth generation arable farmer and suckler beef producer in Devon, told the BBC: \\"It is entirely the maths - it\'s about supply and demand.\\" \\r\\n\\"There\'s a 5% shortfall in cattle on the … [+616 chars]"},{"source":{"id":"bbc-news","name":"BBC News"},"author":"BBC News","title":"\'Our partners were under 50 when they died from heart attacks\'","description":"Widows of two men who died from undiagnosed heart conditions call for more routine screening.","url":"ht
# ...

# %%
df = pd.read_json(response.text)

# I can write a function that extracts the key-value pairs from each row (which is currently in a dictionary format) and then
# Out:
# /var/folders/4y/8v3hsc192dd3bhhzh6m1dcb40000gn/T/ipykernel_28745/2486966893.py:1: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(response.text)

# %%
df
# Out:
#   status  totalResults                                           articles
# 0     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 1     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 2     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 3     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 4     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 5     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 6     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 7     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 8     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 9     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...

# %%
# Extracting the column values


columns = [df.iloc[i].articles.keys() for i in range(0, len(df))]

[*columns[0]]
# Out:
# ['source',
#  'author',
#  'title',
#  'description',
#  'url',
#  'urlToImage',
#  'publishedAt',
#  'content']

# %%
values = [df.iloc[i].articles.values() for i in range(0, len(df))]

[*values]
# Out:
# [dict_values([{'id': 'bbc-news', 'name': 'BBC News'}, 'BBC News', 'Beef drives food inflation to highest in a year', 'The British Retail Consortium says the annual rate of food price rises hit 2.8% in May.', 'https://www.bbc.co.uk/news/articles/ckg41n37990o', 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/2274/live/40dc7be0-3ad2-11f0-bb33-cb43edff610f.jpg', '2025-05-27T10:37:23.9259172Z', 'Jilly Greed, a fourth generation arable farmer and suckler beef producer in Devon, told the BBC: "It is entirely the maths - it\'s about supply and demand." \r\n"There\'s a 5% shortfall in cattle on the … [+616 chars]']),
# ...

# %% [markdown]
# # Constructing the dataframe

# %%
for i in values:
    print ([*i])
# Out:
# [{'id': 'bbc-news', 'name': 'BBC News'}, 'BBC News', 'Beef drives food inflation to highest in a year', 'The British Retail Consortium says the annual rate of food price rises hit 2.8% in May.', 'https://www.bbc.co.uk/news/articles/ckg41n37990o', 'https://ichef.bbci.co.uk/ace/branded_news/1200/cpsprodpb/2274/live/40dc7be0-3ad2-11f0-bb33-cb43edff610f.jpg', '2025-05-27T10:37:23.9259172Z', 'Jilly Greed, a fourth generation arable farmer and suckler beef producer in Devon, told the BBC: "It is entirely the maths - it\'s about supply and demand." \r\n"There\'s a 5% shortfall in cattle on the … [+616 chars]']
# ...

# %%
data = pd.DataFrame(values, columns=[*columns[0]])
data
# Out:
#                                    source    author  \
# 0  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 1  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 2  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 3  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 4  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 5  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 6  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 7  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 8  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 9  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
#
#                                                title  \
# 0    Beef drives food inflation to highest in a year
# 1  'Our partners were under 50 when they died fro...
# 2  New US-backed group says it has begun aid dist...
# 3  Ministers considering scrapping two-child bene...
# 4  Alcohol-related brain damage could affect thou...
# 5  Battle begins over new homes approved in histo...
# ...

# %%
data.iloc[2].content
# Out:
# 'In a statement sent to journalists on Monday night, GHF announced that it had "commenced operations in Gaza" and delivered "truck loads of food to its Secure Distribution Sites, where distribution to… [+2824 chars]'

# %% [markdown]
# # Sentiment Analysis (and clustering)
#
# This will require using some clustering technqiue to group the articles into classes.
#
# I will be specifying clusters according to popular news topics, such as:
#
# - Politics - Covers local, national and international political events, policies, and politicians. This is consistently one of the most read topics.
#
# - Business/Economy - Includes financial markets, companies, industries, jobs, trade, and business leaders. Important for many readers.
#
# - Technology - Updates on innovations, new products, companies in the tech sphere. Widely appealing subject.
#
# - Entertainment - News about movies, music, celebrities, TV shows. Lights topics people enjoy.
#
# - Sports - Reports on professional and college level competitions. Big fan following.
#
# - World - International affairs, events, conflicts and personalities from around the globe.
#
# - Lifestyle - Categories like food, travel, style, home that uplift readers’ lives.
#
# - Health - Medical research, wellness, fitness, conditions and treatments. Relevant to all.
#
# - Science - Covers discoveries, environment topics, and developments in diverse fields.
#
# - Opinion/Editorials - Thought leadership pieces on current discussions and debates.
#
# some key examples include:
# 1. Centroid-based clustering: This type of clustering uses the mean or median of a cluster’s points as the cluster’s centre or centroid. K-means is the most popular centroid-based clustering algorithm.
# 2. Hierarchical clustering: This type of clustering builds a hierarchy of clusters, where each cluster is a subset of the next higher-level cluster. There are two main types of hierarchical clustering: agglomerative and divisive.
# 3. Density-based clustering: This type of clustering groups together points that are close to each other in the feature space. DBSCAN is the most popular density-based clustering algorithm.
# 4. Distribution-based clustering: This type of clustering models the data as a mixture of probability distributions. The Gaussian Mixture Model (GMM) is the most popular distribution-based clustering algorithm.
# 5. Spectral clustering: This type of clustering uses the eigenvectors of a similarity matrix to cluster the data.
# 6. Neural network-based clustering: This type of clustering uses neural networks to learn the cluster structure of the data. Examples of this method are autoencoders and deep embedding clustering.

# %%
# First, I will need to do some text clustering to assign class labels to each news report

# %%
data
# Out:
#                                    source    author  \
# 0  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 1  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 2  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 3  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 4  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 5  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 6  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 7  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 8  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
# 9  {'id': 'bbc-news', 'name': 'BBC News'}  BBC News
#
#                                                title  \
# 0    Beef drives food inflation to highest in a year
# 1  'Our partners were under 50 when they died fro...
# 2  New US-backed group says it has begun aid dist...
# 3  Ministers considering scrapping two-child bene...
# 4  Alcohol-related brain damage could affect thou...
# 5  Battle begins over new homes approved in histo...
# ...

# %%
data.author.unique()
# Out:
# array(['BBC News'], dtype=object)

# %%
# Using K-means clustering 

# As part of preprocessing, we need to tokenize, stem/lemmatize, and remove stop words
from sklearn.feature_extraction.text import TfidfVectorizer 
from sklearn.decomposition import PCA 
from sklearn.cluster import KMeans

from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer

# %%
# tokenizing the words 
data.content = data.content.str.lower()

content_tokenized = data.content.apply(word_tokenize)

# %%
content_tokenized
# Out:
# 0    [jilly, greed, ,, a, fourth, generation, arabl...
# 1    [research, by, the, bhf, also, found, that, in...
# 2    [in, a, statement, sent, to, journalists, on, ...
# 3    [in, a, speech, on, monday, ,, reform, uk, lea...
# 4    [``, we, see, a, massive, change, in, people, ...
# 5    [on, the, edge, of, buckingham, in, southern, ...
# 6    [staff, at, the, chelsea, and, westminster, ``...
# 7    [the, image, depicts, a, frowning, churchill, ...
# 8    [apprenticeships, in, england, are, available,...
# 9    [prime, minister, sir, keir, starmer, is, bein...
# Name: content, dtype: object

# %%
## removing stop words 

from nltk.corpus import stopwords
 
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than',
# ...

# %%
content_tokenized
# Out:
# 0    [jilly, greed, ,, a, fourth, generation, arabl...
# 1    [research, by, the, bhf, also, found, that, in...
# 2    [in, a, statement, sent, to, journalists, on, ...
# 3    [in, a, speech, on, monday, ,, reform, uk, lea...
# 4    [``, we, see, a, massive, change, in, people, ...
# 5    [on, the, edge, of, buckingham, in, southern, ...
# 6    [staff, at, the, chelsea, and, westminster, ``...
# 7    [the, image, depicts, a, frowning, churchill, ...
# 8    [apprenticeships, in, england, are, available,...
# 9    [prime, minister, sir, keir, starmer, is, bein...
# Name: content, dtype: object

# %%
pd.Series(content_tokenized)
# Out:
# 0    [jilly, greed, ,, a, fourth, generation, arabl...
# 1    [research, by, the, bhf, also, found, that, in...
# 2    [in, a, statement, sent, to, journalists, on, ...
# 3    [in, a, speech, on, monday, ,, reform, uk, lea...
# 4    [``, we, see, a, massive, change, in, people, ...
# 5    [on, the, edge, of, buckingham, in, southern, ...
# 6    [staff, at, the, chelsea, and, westminster, ``...
# 7    [the, image, depicts, a, frowning, churchill, ...
# 8    [apprenticeships, in, england, are, available,...
# 9    [prime, minister, sir, keir, starmer, is, bein...
# Name: content, dtype: object

# %%
stop_words = set(stopwords.words('english'))

for i in range(len(content_tokenized)): 
    content_tokenized[i] = [w for w in content_tokenized[i] if w not in stop_words]

# %%
content_tokenized
# Out:
# 0    [jilly, greed, ,, fourth, generation, arable, ...
# 1    [research, bhf, also, found, yorkshire, humber...
# 2    [statement, sent, journalists, monday, night, ...
# 3    [speech, monday, ,, reform, uk, leader, nigel,...
# 4    [``, see, massive, change, people, time, leave...
# 5    [edge, buckingham, southern, england, ,, quiet...
# 6    [staff, chelsea, westminster, ``, acted, line,...
# 7    [image, depicts, frowning, churchill, ,, 67, t...
# 8    [apprenticeships, england, available, aged, 16...
# 9    [prime, minister, sir, keir, starmer, kept, up...
# Name: content, dtype: object

# %%
vectorizer = TfidfVectorizer()

# %%
list_content_tokenized = list(content_tokenized)

# %%
content_tokenized_vectorized = vectorizer.fit_transform(data.content)

# %%
np.shape(content_tokenized_vectorized)
# Out:
# (10, 224)

# %%
vectorizer.get_feature_names_out()
# Out:
# array(['1016', '1277', '1402', '16', '17', '190', '2020', '2022', '2049',
#        '2763', '2824', '320', '59', '616', '67', '69', '743', '898',
#        '901', 'abolish', 'about', 'acted', 'after', 'aged', 'alcohol',
#        'all', 'already', 'also', 'and', 'announced', 'another',
#        'appalling', 'apprenticeships', 'arable', 'are', 'around', 'as',
#        'at', 'august', 'available', 'bbc', 'beef', 'been', 'being',
#        'between', 'bevan', 'bhf', 'both', 'brynawel', 'buckingham', 'but',
#        'by', 'canadian', 'cap', 'cases', 'cattle', 'change', 'chars',
#        'chelsea', 'churchill', 'combine', 'commenced', 'committed',
#        'complete', 'cottages', 'could', 'delivered', 'demand',
#        'democrats', 'depending', 'depicts', 'developments', 'devon',
#        'diagnosed', 'dilemma', 'distribution', 'dotted', 'drink', 'edge',
#        'england', 'entirely', 'evolved', 'expected', 'failure', 'farage',
# ...

# %%
# Dropping the "url" column 

data.drop(['url', 'source', 'urlToImage', 'publishedAt', 'author'], axis=1, inplace=True)

# %%
data.head()
# Out:
#                                                title  \
# 0    Beef drives food inflation to highest in a year
# 1  'Our partners were under 50 when they died fro...
# 2  New US-backed group says it has begun aid dist...
# 3  Ministers considering scrapping two-child bene...
# 4  Alcohol-related brain damage could affect thou...
#
#                                          description  \
# 0  The British Retail Consortium says the annual ...
# 1  Widows of two men who died from undiagnosed he...
# 2  The Gaza Humanitarian Foundation says Palestin...
# 3  The education secretary says the policy pushes...
# 4  Drinking 35 units of alcohol a week for five y...
#
#                                              content
# 0  jilly greed, a fourth generation arable farmer...
# 1  research by the bhf also found that in yorkshi...
# 2  in a statement sent to journalists on monday n...
# 3  in a speech on monday, reform uk leader nigel ...
# 4  "we see a massive change in people by the time...

# %%
def text_lower(data):
    return data.lower() 

def tokenize(data): 
    return word_tokenize(data)

def remove_stop_words(data): 
    return [w for w in data if w not in stop_words]

# %%
data
# Out:
#                                                title  \
# 0    Beef drives food inflation to highest in a year
# 1  'Our partners were under 50 when they died fro...
# 2  New US-backed group says it has begun aid dist...
# 3  Ministers considering scrapping two-child bene...
# 4  Alcohol-related brain damage could affect thou...
# 5  Battle begins over new homes approved in histo...
# 6  Abortion arrest: Leaked recording reveals poli...
# 7  Churchill photo thief sentenced to two years i...
# 8  Apprenticeship shakeup to shift focus to under...
# 9  What we know about the Liverpool FC parade inc...
#
#                                          description  \
# 0  The British Retail Consortium says the annual ...
# 1  Widows of two men who died from undiagnosed he...
# 2  The Gaza Humanitarian Foundation says Palestin...
# 3  The education secretary says the policy pushes...
# 4  Drinking 35 units of alcohol a week for five y...
# 5  Charity launches legal challenge as it says pr...
# ...

# %%
# I need to stem and lemmatize the words

# %%
from nltk.stem.porter import PorterStemmer

# %%
stemmer = PorterStemmer() 

for i in range(len(data.title)): 
    data.title[i] = [stemmer.stem(a) for a in data.title[i]]


for i in range(len(data.description)): 
    data.description[i] = [stemmer.stem(a) for a in data.description[i]]

for i in range(len(data.content)):
    data.content[i] = [stemmer.stem(a) for a in data.content[i]]
# Out:
# /var/folders/4y/8v3hsc192dd3bhhzh6m1dcb40000gn/T/ipykernel_28745/503312043.py:4: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   data.title[i] = [stemmer.stem(a) for a in data.title[i]]
# ...

# %%
data.shape
# Out:
# (10, 3)

# %%
data
# Out:
#                                                title  \
# 0  [b, e, e, f,  , d, r, i, v, e, s,  , f, o, o, ...
# 1  [', o, u, r,  , p, a, r, t, n, e, r, s,  , w, ...
# 2  [n, e, w,  , u, s, -, b, a, c, k, e, d,  , g, ...
# 3  [m, i, n, i, s, t, e, r, s,  , c, o, n, s, i, ...
# 4  [a, l, c, o, h, o, l, -, r, e, l, a, t, e, d, ...
# 5  [b, a, t, t, l, e,  , b, e, g, i, n, s,  , o, ...
# 6  [a, b, o, r, t, i, o, n,  , a, r, r, e, s, t, ...
# 7  [c, h, u, r, c, h, i, l, l,  , p, h, o, t, o, ...
# 8  [a, p, p, r, e, n, t, i, c, e, s, h, i, p,  , ...
# 9  [w, h, a, t,  , w, e,  , k, n, o, w,  , a, b, ...
#
#                                          description  \
# 0  [t, h, e,  , b, r, i, t, i, s, h,  , r, e, t, ...
# 1  [w, i, d, o, w, s,  , o, f,  , t, w, o,  , m, ...
# 2  [t, h, e,  , g, a, z, a,  , h, u, m, a, n, i, ...
# 3  [t, h, e,  , e, d, u, c, a, t, i, o, n,  , s, ...
# 4  [d, r, i, n, k, i, n, g,  , 3, 5,  , u, n, i, ...
# 5  [c, h, a, r, i, t, y,  , l, a, u, n, c, h, e, ...
# ...

# %%
# reminder that the difference between embedding and vectorization is that embedding is a mapping of a word to a vector space, while vectorization is the process of converting text into a numerical representation.
# Embedding is a more general term that encompasses various techniques, including vectorization.
# Vectorization is a specific method of embedding that focuses on converting text into numerical vectors.
# Embedding is a more general term that encompasses various techniques, including vectorization.

# %%
## vectorisation (i need to vectorise each row and column)
vectoriser = TfidfVectorizer()
a = vectoriser.fit_transform(data.title[0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 ## vectorisation (i need to vectorise each row and column)
#       2 vectoriser = TfidfVectorizer()
# ----> 3 a = vectoriser.fit_transform(data.title[0])
#
# File /opt/miniconda3/envs/news_project/lib/python3.13/site-packages/sklearn/feature_extraction/text.py:2104, in TfidfVectorizer.fit_transform(self, raw_documents, y)
#    2097 self._check_params()
#    2098 self._tfidf = TfidfTransformer(
#    2099     norm=self.norm,
#    2100     use_idf=self.use_idf,
#    2101     smooth_idf=self.smooth_idf,
#    2102     sublinear_tf=self.sublinear_tf,
#    2103 )
# -> 2104 X = super().fit_transform(raw_documents)
#    2105 self._tfidf.fit(X)
#    2106 # X is already a transformed view of raw_documents so
#    2107 # we set copy to False
#
# ...

# %%
a

# %%
np.shape(a)

# %%
vectoriser.get_feature_names_out()

# %% [markdown]
# # Summariser

# %%
from huggingface_hub import login
from transformers import AutoTokenizer, AutoModelForCausalLM
from transformers import pipeline
from huggingface_hub import login
import transformers
import torch

import joblib 
from accelerate import Accelerator
accelerator = Accelerator()
device = accelerator.device


print ("Logging in...")
login(token="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")

# %%
model_id = "meta-llama/Meta-Llama-3.1-8B-Instruct"

# %%
summarizer = transformers.pipeline("summarization", device_map=device, model=model_id)

# %%
data.iloc[1].content

# %%
example_text_summarised = summarizer(data.iloc[0].content)

with open("example_text_summarised.txt", "w") as f: 
    f.write(f"{example_text_summarised}")
    f.close()

# %%
with open("example_text.txt", "w") as f: 
    f.write(f"{data.iloc[0].content}")
    f.close()

# %%
data.iloc[0].content

# %%
article ="""
Vice-presidential candidates JD Vance and Tim Walz have agreed to a debate on 1 October.

CBS said the debate in New York would be moderated by journalists Norah O'Donnell and Margaret Brennan, adding: "We look forward to... providing voters with an opportunity to hear directly from the vice-presidential candidates."

"See you on October 1, JD," Kamala Harris's running mate Mr Walz posted on X on Wednesday.

Mr Vance, Donald Trump's running mate, then on Thursday announced his agreement to the October date.

In his X post, Mr Vance challenged Mr Walz to a separate CNN debate on 18 September.

"I look forward to seeing you at both!" Mr Vance posted on X.

Mr Walz has not yet commented on the possibility of a second meet up.

Trump and Ms Harris, meanwhile, have agreed to a debate on ABC on 10 September.

"I am looking forward to debating Donald Trump," Ms Harris said last week. "I hear he’s finally committed to it and I’m looking forward to it."

Trump had initially said he would only debate his opponent on Fox News. Ms Harris rejected those conditions, arguing that the Trump campaign had already agreed to ABC when it was presumed Joe Biden would be the Democratic nominee.

During a press conference last week, Trump said: "We think we should do three debates", and suggested two additional debates against Ms Harris that he said would be hosted by Fox News and NBC.

The Harris campaign has not specifically commented on the other two debates proposed by Trump.

Ms Harris has said she would be open to additional dates, though her campaign said last week that "Trump has to show up" to the ABC debate before they confirm any further showdowns.

NBC News is reportedly in discussions with both campaigns about a potential debate this autumn, the New York Times reported.

Mr Biden's poor debate performance against Trump in June triggered the crisis over his candidacy that ultimately led to calls for him to drop out of the race ahead of November's election.
"""

# %%
summarizer(article)

# %% [markdown]
# # Translation

# %%
from googletrans import Translator

# %%
translator = Translator() 


translated = translator.translate(data['title'].iloc[0], dest='id')

# %%
data['title'].iloc[0]

# %%
translated.text

# %% [markdown]
# # Entire Pipeline

# %%
## Importing the dependencies 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
import scipy.stats as stats 
import numpy as np 
import requests 
import json

# What if I use the sys module to pass arguments into the script? 
import sys 

# the only argument will be the data itself (including the url) 

print (f"argument list: {sys.argv}")






class data_processing: 
    # This pipeline will depend on pandas
    def __init__(self, url): 
        self.url = url

    def import_data(self): 
        print ("Importing the data...")
        response = requests.get(url)
        print (f"status code: {response.status_code}")

    def read_data(self): 
        print ("reading the data...")
        return pd.read_json(response.text)
    def clean_data(self): 
        print ("Cleaning the data...")
        columns = [df.iloc[i].articles.keys() for i in range(0, len(df))]

        values = [df.iloc[i].articles.values() for i in range(0, len(df))]
        data = pd.DataFrame(values, columns=[*columns[0]])

        print ("output")
        data.drop(['source', 'urlToImage', 'author'], axis=1, inplace=True) 
        print (data.head())
        # returning the cleaned dataset 

        return data 

    def text_clustering(self):
        pass 


    def summariser(self): 
        pass 

    def translation(self): 
        
        pass
# Out:
# argument list: ['/opt/miniconda3/envs/news_project/lib/python3.13/site-packages/ipykernel_launcher.py', '-f', '/Users/thomasnguyen/Library/Jupyter/runtime/kernel-7f0f6d3c-286f-4efd-95f6-28c92c1f4d40.json']

# %%
# testing the pipeline 
url = "https://api.thenewsapi.com/v1/news/all?api_token=FwP6OI9ed4hixbo6HNr3vhKPxKS3iqRjkqwHGJx3&language=en&limit=3"
url = "https://newsapi.org/v2/top-headlines?sources=bbc-news&apiKey=762f924e2bd9490382a4b4176ad8dec2"

test = data_processing(url)

# %%
test.import_data()
# Out:
# Importing the data...
# status code: 200

# %%
a = test.read_data()
# Out:
# reading the data...
# /var/folders/4y/8v3hsc192dd3bhhzh6m1dcb40000gn/T/ipykernel_28745/3286673518.py:34: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   return pd.read_json(response.text)

# %%
a
# Out:
#   status  totalResults                                           articles
# 0     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 1     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 2     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 3     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 4     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 5     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 6     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 7     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 8     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...
# 9     ok            10  {'source': {'id': 'bbc-news', 'name': 'BBC New...

# %%
clean_data = test.clean_data()
# Out:
# Cleaning the data...
# output
#      author                                              title  \
# 0  BBC News    Beef drives food inflation to highest in a year
# 1  BBC News  'Our partners were under 50 when they died fro...
# 2  BBC News  New US-backed group says it has begun aid dist...
# 3  BBC News  Ministers considering scrapping two-child bene...
# 4  BBC News  Alcohol-related brain damage could affect thou...
#
#                                          description  \
# 0  The British Retail Consortium says the annual ...
# 1  Widows of two men who died from undiagnosed he...
# 2  The Gaza Humanitarian Foundation says Palestin...
# 3  The education secretary says the policy pushes...
# 4  Drinking 35 units of alcohol a week for five y...
#
#                                                 url  \
# 0  https://www.bbc.co.uk/news/articles/ckg41n37990o
# 1  https://www.bbc.co.uk/news/articles/cq5435q493do
# 2  https://www.bbc.co.uk/news/articles/cev41em3r9lo
# ...

# %%
clean_data
# Out:
#      author                                              title  \
# 0  BBC News    Beef drives food inflation to highest in a year
# 1  BBC News  'Our partners were under 50 when they died fro...
# 2  BBC News  New US-backed group says it has begun aid dist...
# 3  BBC News  Ministers considering scrapping two-child bene...
# 4  BBC News  Alcohol-related brain damage could affect thou...
# 5  BBC News  Battle begins over new homes approved in histo...
# 6  BBC News  Abortion arrest: Leaked recording reveals poli...
# 7  BBC News  Churchill photo thief sentenced to two years i...
# 8  BBC News  Apprenticeship shakeup to shift focus to under...
# 9  BBC News  What we know about the Liverpool FC parade inc...
#
#                                          description  \
# 0  The British Retail Consortium says the annual ...
# 1  Widows of two men who died from undiagnosed he...
# 2  The Gaza Humanitarian Foundation says Palestin...
# 3  The education secretary says the policy pushes...
# ...

# %%
data.shape
# Out:
# (10, 3)

# %%
## clustering it
